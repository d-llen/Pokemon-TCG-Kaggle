# %% [markdown]
# # Notes
#
# PACKAGE CMD, RUN IN TERMINAL IN BOT FOLDER DIRECTORY: tar -czvf submission.tar.gz *
#
# -built simulator \
# -started with lucario deck \
# -noticed bias to agent 1 over 100 and 500 games, updated code to so both agents are passed first to code same amnt of times \
# -tried editing target selection based on prize cards, no benefit. trying fixing resource management \
# -added other 3 template decks to test against. added a script which battles all 4 base bots. \
# -Tried editing retreat logic, buns results \
# -added logic to value removing opponent stadium w gravity mtn; prevent decking out using carmine/lillies determination when low on cards; use boss orders to disrupt opponent when needed \

# %% [markdown]
# # Weaknesses
#
# -ran out of cards in deck vs alakazam deck \
# -opponent took all prize cards using alakazam deck \
# -opponent took all prize cards using alakazam deck \
# -opponent used crustle and neutralizaton zone -> did no damage and ran out of cards in deck \
# -starmie deck took all prize cards \
# -opponent used crustle and i ran out of cards in deck \

# %% [markdown]
# # Meta
# -Mega Kangaskhan Ex / (Crustle) \
# -Marnie's Grimmsnarl Ex\
# -Starmie Ex/ (Dusknoir)\
# -Okidogi / Barbaracle\
# -Alakazam\
